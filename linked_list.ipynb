# %%
# Linked list

# %%
class Node:
    # this is like main home
    def __init__(self,data):
        self.data = data
        self.next = None

class SLL:
    # kind of a map to reach the home
    def __init__(self):
        self.head = None


    def traversal(self):
        print()
        if self.head is None:
            print('Empty linked list!!!')
        else:
            a  = self.head
            while a is not None:
                print(a.data, end=' ')
                a=a.next

    def insert_beg(self,data):
        if self.head is not None:
            nb = Node(data)
            nb.next = self.head
            self.head = nb

    def insert_end(self,data):
        print()
        nb = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next
        a.next = nb

    def insert_pos(self,data,position):
        print()
        nb = Node(data)
        a = self.head
        for i in range(1,position-1):
            a = a.next
        nb.next = a.next
        a.next = nb

    def del_beg(self):
        print()
        a = self.head
        self.head = a.next
        #a.next = None # not ncesessar but usefull

    def del_end(self):
        print()
        prev = self.head
        a  = self.head.next

        while a.next is not None:

            a=a.next
            prev = prev.next
        prev.next= None

    def del_pos(self,position):
        print()
        prev =self.head
        a = self.head.next

        for i in range(1,position-1):
            a = a.next 
            prev = prev.next  
        prev.next = a.next
        a.next=None

# %%
l = [1,6,5,4]
rev = []
for i in l:
    rev.insert(0,i)
print(rev)

# %%
n1 = Node(3)
sll = SLL()
sll.head = n1
n2 = Node(4)
n1.next = n2
n3 = Node(5)
n2.next = n3
n4 = Node(6)
n3.next = n4


sll.insert_beg(14)
sll.traversal()

sll.insert_end(100)
sll.traversal()
sll.insert_pos(25,3)
sll.traversal()
sll.del_beg()
sll.del_end()
sll.traversal()
sll.del_pos(5)
sll.traversal()

# %%
sll.head =

# %%
# Doubly linked list

# %%
class Node1:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DLL:
    def __init__(self):
        self.head = None

    def forward_traversal(self):
        print()
        if self.head is None:
            print('Empty linked list!!!')
        else:
            a = self.head
            while a is not None:
                print(a.data, end=' ')
                a = a.next
        print()  # To ensure the output ends with a newline

    def backward_traversal(self):
        print()
        if self.head is None:
            print('Empty linked list!!!')
        else:
            a = self.head
            while a.next is not None:
                a = a.next
            while a is not None:
                print(a.data, end=' ')
                a = a.prev
        print()  # To ensure the output ends with a newline

    def middle(self):
        if self.head is None:
            return None
        
        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None:
            slow = slow.next
            fast = fast.next.next

        return slow.data if slow else None

    def cycle_det(self):
        if self.head is None:
            return 'No nodes in the list'
        
        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None:
            slow = slow.next
            fast = fast.next.next

            if slow == fast:  # Cycle detected
                return 'Cycle detected'
        
        return 'No cycles detected'

# Example usage:
dll = DLL()
n1 = Node1(4)
dll.head = n1
n2 = Node1(90)
n2.prev = n1
n1.next = n2
n3 = Node1(6)
n3.prev = n2
n2.next = n3
n3.next = n1  # Creating a cycle

# Testing the functions
dll.forward_traversal()
print("Middle node:", dll.middle())
print(dll.cycle_det())  # Should output 'Cycle detected'
# Out:
# 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90
# ...

# %%
# Create nodes
n1 = Node1(4)
dll = DLL()
dll.head = n1
n2 = Node1(90)
n2.prev = n1
n1.next = n2
n3 = Node1(6)
n3.prev = n2
n2.next = n3

n3.next = n1

# %%
dll.forward_traversal()
dll.backward_traversal()
dll.middle()
dll.cycle_det()
# Out:
# 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90 6 4 90
# ...

# %%
n2.next

# %%
#traversal in ll

# %%
class Node1:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DLL:
    def __init__(self):
        self.head = None

    def forward_traversal(self):
        print()
        if self.head is None:
            print('Empty linked list!!!')
        else:
            # Call cycle detection before starting traversal
            if self.cycle_det() == 'Cycle detected':
                print("Cycle detected, stopping traversal.")
                return

            a = self.head
            while a is not None:
                print(a.data, end=' ')
                a = a.next
            print()  # To ensure the output ends with a newline

    def backward_traversal(self):
        print()
        if self.head is None:
            print('Empty linked list!!!')
        else:
            a = self.head
            while a.next is not None:
                a = a.next
            while a is not None:
                print(a.data, end=' ')
                a = a.prev
            print()  # To ensure the output ends with a newline

    def middle(self):
        if self.head is None:
            return None
        
        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None:
            slow = slow.next
            fast = fast.next.next

        return slow.data if slow else None

    def cycle_det(self):
        if self.head is None:
            return 'No nodes in the list'
        
        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None:
            slow = slow.next
            fast = fast.next.next

            if slow == fast:
                return 'Cycle detected'
        return 'No cycles detected'

# Example usage:
dll = DLL()
n1 = Node1(4)
dll.head = n1
n2 = Node1(90)
n2.prev = n1
n1.next = n2
n3 = Node1(6)
n3.prev = n2
n2.next = n3
n3.next = n1  # Creating a cycle

# Testing the functions
dll.forward_traversal()
print("Middle node:", dll.middle())
print(dll.cycle_det())
# Out:
# Cycle detected, stopping traversal.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 82
#      80 # Testing the functions
#      81 dll.forward_traversal()
# ---> 82 print("Middle node:", dll.middle())
#      83 print(dll.cycle_det())
#
# Cell In[8], line 47, in DLL.middle(self)
#      44 slow = self.head
#      45 fast = self.head
# ---> 47 while fast is not None and fast.next is not None:
#      48     slow = slow.next
#      49     fast = fast.next.next
#
# KeyboardInterrupt:
